# %%
import pandas as pd
import numpy as np

# Load dataset
df = pd.read_csv(r"C:\Users\polka\OneDrive\Desktop\Tourist influx prediction\Tourism dataset.csv")   # Change path if needed

print("Original Shape:", df.shape)

print("\nDataset Info:")
print(df.info())

print("\nFirst 5 Rows:")
print(df.head())
# Out:
# Original Shape: (63, 37)
#
# Dataset Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 63 entries, 0 to 62
# Data columns (total 37 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country of Nationality         63 non-null     object
#  1   2014 1st quarter (Jan-March)   63 non-null     float64
#  2   2014 2nd quarter (Apr-June)    63 non-null     float64
#  3   2014 3rd quarter (July-Sep)    63 non-null     float64
#  4   2014 4th quarter (Oct-Dec))    63 non-null     float64
#  5   2015 1st quarter (Jan-March)   63 non-null     float64
#  6   2015 2nd quarter (Apr-June)    63 non-null     float64
#  7   2015 3rd quarter (July-Sep)    63 non-null     float64
#  8   2015 4th quarter (Oct-Dec)     63 non-null     float64
#  9   2016 1st quarter (Jan-March)   63 non-null     float64
#  10  2016 2nd quarter (Apr-June)    63 non-null     float64
#  11  2016 3rd quarter (July-Sep)    63 non-null     float64
#  12  2016 4th quarter (Oct-Dec)     63 non-null     float64
#  13  2017 1st quarter (Jan-March)   63 non-null     float64
#  14  2017 2nd quarter (Apr-June)    63 non-null     float64
#  15  2017 3rd quarter (July-Sep)    63 non-null     float64
#  16  2017 4th quarter (Oct-Dec)     63 non-null     float64
#  17  2018 1st quarter (Jan-March)   63 non-null     float64
#  18  2018 2nd quarter (Apr-June)    63 non-null     float64
#  19  2018 3rd quarter (July-Sep)    63 non-null     float64
#  20  2018 4th quarter (Oct-Dec)     63 non-null     float64
#  21  2019 1st quarter (Jan-March)   63 non-null     float64
#  22  2019 2nd quarter (Apr-June)    63 non-null     float64
#  23  2019 3rd quarter (July-Sep)    63 non-null     float64
#  24  2019 4th quarter (Oct-Dec)     63 non-null     float64
#  25  2020 1st quarter (Jan-March)   63 non-null     float64
#  26  Unnamed: 26                    0 non-null      float64
#  27  2020 2nd quarter (Apr-June)    63 non-null     float64
#  28  Unnamed: 28                    0 non-null      float64
#  29  2020 3rd quarter (July-Sep)    63 non-null     float64
#  30  Unnamed: 30                    0 non-null      float64
#  31  2020 4th quarter (Oct-Dec)     63 non-null     float64
#  32  average_temp(*c)               63 non-null     int64
#  33  Relative Humidity(at 2m)%      63 non-null     float64
#  34  Precipitation (mm/day)         63 non-null     float64
#  35  Cultural Fests                 63 non-null     int64
#  36  Holidays                       63 non-null     int64
# dtypes: float64(33), int64(3), object(1)
# memory usage: 18.3+ KB
# None
#
# First 5 Rows:
#      Country of Nationality  2014 1st quarter (Jan-March)  \
# 0                    Canada                          33.1
# 1  United States Of America                          25.7
# 2                 Argentina                          46.8
# 3                    Brazil                          31.0
# 4                    Mexico                          23.6
#
#    2014 2nd quarter (Apr-June)  2014 3rd quarter (July-Sep)  \
# 0                         14.5                         15.7
# 1                         22.0                         20.6
# 2                         15.6                         13.9
# 3                         18.8                         18.7
# 4                         20.3                         26.5
#
#    2014 4th quarter (Oct-Dec))  2015 1st quarter (Jan-March)   \
# 0                         36.7                           34.2
# 1                         31.7                           26.4
# 2                         23.7                           40.6
# 3                         31.5                           34.8
# 4                         29.6                           28.1
#
#    2015 2nd quarter (Apr-June)  2015 3rd quarter (July-Sep)   \
# 0                         14.5                          15.9
# 1                         22.1                          19.6
# 2                         17.5                          14.6
# 3                         19.0                          19.6
# 4                         21.3                          23.4
#
#    2015 4th quarter (Oct-Dec)   2016 1st quarter (Jan-March)   ...  \
# 0                         35.4                           34.5  ...
# 1                         31.9                           25.7  ...
# 2                         27.3                           41.7  ...
# 3                         26.6                           29.7  ...
# 4                         27.2                           25.4  ...
#
#    2020 2nd quarter (Apr-June)  Unnamed: 28  2020 3rd quarter (July-Sep)   \
# 0                          0.3          NaN                           2.0
# 1                          0.9          NaN                           3.8
# 2                          0.2          NaN                           0.5
# 3                          0.9          NaN                           2.3
# 4                          0.5          NaN                           1.2
#
#    Unnamed: 30  2020 4th quarter (Oct-Dec)   average_temp(*c)  \
# 0          NaN                          8.8                27
# 1          NaN                         10.8                27
# 2          NaN                          1.5                27
# 3          NaN                          4.1                28
# 4          NaN                          2.4                30
#
#    Relative Humidity(at 2m)%  Precipitation (mm/day)  Cultural Fests  Holidays
# 0                      63.44                     0.0               7         9
# 1                      61.88                     0.0               6         8
# 2                      64.56                     0.0               4         9
# 3                      70.00                     0.0               5         7
# 4                      73.62                     0.0               4         6
#
# [5 rows x 37 columns]

# %%
duplicates = df.duplicated().sum()
print("\nDuplicate Rows:", duplicates)

df = df.drop_duplicates()
print("Shape after removing duplicates:", df.shape)
# Out:
# Duplicate Rows: 0
# Shape after removing duplicates: (63, 37)

# %%
df = df.loc[:, ~df.columns.str.contains('^Unnamed')]
print(df)
# Out:
#       Country of Nationality  2014 1st quarter (Jan-March)  \
# 0                     Canada                          33.1
# 1   United States Of America                          25.7
# 2                  Argentina                          46.8
# 3                     Brazil                          31.0
# 4                     Mexico                          23.6
# ..                       ...                           ...
# 58                     Japan                          28.0
# 59       Korea (Republic Of                           32.1
# 60  Republic Of China Taiwan                          29.7
# 61                 Australia                          25.2
# 62               New Zealand                          25.5
#
#     2014 2nd quarter (Apr-June)  2014 3rd quarter (July-Sep)  \
# 0                          14.5                         15.7
# 1                          22.0                         20.6
# 2                          15.6                         13.9
# 3                          18.8                         18.7
# 4                          20.3                         26.5
# ..                          ...                          ...
# 58                         19.7                         25.1
# 59                         19.1                         22.6
# 60                         16.8                         22.7
# 61                         17.1                         18.4
# 62                         16.3                         18.3
#
#     2014 4th quarter (Oct-Dec))  2015 1st quarter (Jan-March)   \
# 0                          36.7                           34.2
# 1                          31.7                           26.4
# 2                          23.7                           40.6
# 3                          31.5                           34.8
# 4                          29.6                           28.1
# ..                          ...                            ...
# 58                         27.2                           28.0
# 59                         26.2                           31.1
# 60                         30.8                           32.8
# 61                         39.3                           25.7
# 62                         39.9                           25.4
#
#     2015 2nd quarter (Apr-June)  2015 3rd quarter (July-Sep)   \
# 0                          14.5                          15.9
# 1                          22.1                          19.6
# 2                          17.5                          14.6
# 3                          19.0                          19.6
# 4                          21.3                          23.4
# ..                          ...                           ...
# 58                         19.0                          26.0
# 59                         19.7                          23.1
# 60                         16.9                          22.3
# 61                         16.7                          17.6
# 62                         16.5                          17.9
#
#     2015 4th quarter (Oct-Dec)   2016 1st quarter (Jan-March)   ...  \
# 0                          35.4                           34.5  ...
# 1                          31.9                           25.7  ...
# 2                          27.3                           41.7  ...
# 3                          26.6                           29.7  ...
# 4                          27.2                           25.4  ...
# ..                          ...                            ...  ...
# 58                         30.0                           28.6  ...
# 59                         26.1                           30.1  ...
# 60                         28.0                           32.6  ...
# 61                         40.0                           26.9  ...
# 62                         40.2                           25.3  ...
#
#     2019 4th quarter (Oct-Dec)   2020 1st quarter (Jan-March)   \
# 0                          34.5                           88.9
# 1                          32.3                           84.5
# 2                          25.1                           97.8
# 3                          29.7                           92.6
# 4                          31.2                           95.8
# ..                          ...                            ...
# 58                         26.7                           93.4
# 59                         25.3                           81.0
# 60                         27.2                           97.7
# 61                         39.5                           95.2
# 62                         38.6                           94.2
#
#     2020 2nd quarter (Apr-June)  2020 3rd quarter (July-Sep)   \
# 0                           0.3                           2.0
# 1                           0.9                           3.8
# 2                           0.2                           0.5
# 3                           0.9                           2.3
# 4                           0.5                           1.2
# ..                          ...                           ...
# 58                          0.5                           1.7
# 59                          3.2                           6.1
# 60                          0.0                           0.5
# 61                          0.4                           1.2
# 62                          0.8                           1.5
#
#     2020 4th quarter (Oct-Dec)   average_temp(*c)  Relative Humidity(at 2m)%  \
# 0                           8.8                27                      63.44
# 1                          10.8                27                      61.88
# 2                           1.5                27                      64.56
# 3                           4.1                28                      70.00
# 4                           2.4                30                      73.62
# ..                          ...               ...                        ...
# 58                          4.3                27                      69.00
# 59                          9.6                26                      65.81
# 60                          1.7                26                      59.06
# 61                          3.2                25                      58.56
# 62                          3.5                26                      66.19
#
#     Precipitation (mm/day)  Cultural Fests  Holidays
# 0                      0.0               7         9
# 1                      0.0               6         8
# 2                      0.0               4         9
# 3                      0.0               5         7
# 4                      0.0               4         6
# ..                     ...             ...       ...
# 58                     0.0               6         9
# 59                     0.0               7        11
# 60                     0.0               7         9
# 61                     0.0               6         8
# 62                     0.0               4         9
#
# [63 rows x 34 columns]

# %%
df.rename(columns={'2014 4th quarter (Oct-Dec))':
                   '2014 4th quarter (Oct-Dec)'}, inplace=True)

# HANDLE MISSING VALUES

print("\nMissing Values Before Cleaning:")
print(df.isnull().sum())
# Out:
# Missing Values Before Cleaning:
# Country of Nationality           0
# 2014 1st quarter (Jan-March)     0
# 2014 2nd quarter (Apr-June)      0
# 2014 3rd quarter (July-Sep)      0
# 2014 4th quarter (Oct-Dec)       0
# 2015 1st quarter (Jan-March)     0
# 2015 2nd quarter (Apr-June)      0
# 2015 3rd quarter (July-Sep)      0
# 2015 4th quarter (Oct-Dec)       0
# 2016 1st quarter (Jan-March)     0
# 2016 2nd quarter (Apr-June)      0
# 2016 3rd quarter (July-Sep)      0
# 2016 4th quarter (Oct-Dec)       0
# 2017 1st quarter (Jan-March)     0
# 2017 2nd quarter (Apr-June)      0
# 2017 3rd quarter (July-Sep)      0
# 2017 4th quarter (Oct-Dec)       0
# 2018 1st quarter (Jan-March)     0
# 2018 2nd quarter (Apr-June)      0
# 2018 3rd quarter (July-Sep)      0
# 2018 4th quarter (Oct-Dec)       0
# 2019 1st quarter (Jan-March)     0
# 2019 2nd quarter (Apr-June)      0
# 2019 3rd quarter (July-Sep)      0
# 2019 4th quarter (Oct-Dec)       0
# 2020 1st quarter (Jan-March)     0
# 2020 2nd quarter (Apr-June)      0
# 2020 3rd quarter (July-Sep)      0
# 2020 4th quarter (Oct-Dec)       0
# average_temp(*c)                 0
# Relative Humidity(at 2m)%        0
# Precipitation (mm/day)           0
# Cultural Fests                   0
# Holidays                         0
# dtype: int64

# %%
# Fill numeric columns with median
numeric_cols = df.select_dtypes(include=['int64', 'float64']).columns
df[numeric_cols] = df[numeric_cols].apply(lambda x: x.fillna(x.median()))

# Fill categorical columns with mode
categorical_cols = df.select_dtypes(include=['object']).columns
df[categorical_cols] = df[categorical_cols].apply(lambda x: x.fillna(x.mode()[0]))

# %%
df.columns = df.columns.str.strip()
for col in df.columns:
    if "quarter" in col.lower():
        df[col] = pd.to_numeric(df[col], errors='coerce')

# ---------------------------------------------
# 6️⃣ CREATE TOTAL INFLOW COLUMN
# ---------------------------------------------
tourism_cols = [col for col in df.columns if "quarter" in col.lower()]

if tourism_cols:
    df["Total_Inflow"] = df[tourism_cols].sum(axis=1)

# %%
print("\nFinal Shape:", df.shape)
print("\nFinal Missing Values:")
print(df.isnull().sum())
# Out:
# Final Shape: (63, 35)
#
# Final Missing Values:
# Country of Nationality          0
# 2014 1st quarter (Jan-March)    0
# 2014 2nd quarter (Apr-June)     0
# 2014 3rd quarter (July-Sep)     0
# 2014 4th quarter (Oct-Dec)      0
# 2015 1st quarter (Jan-March)    0
# 2015 2nd quarter (Apr-June)     0
# 2015 3rd quarter (July-Sep)     0
# 2015 4th quarter (Oct-Dec)      0
# 2016 1st quarter (Jan-March)    0
# 2016 2nd quarter (Apr-June)     0
# 2016 3rd quarter (July-Sep)     0
# 2016 4th quarter (Oct-Dec)      0
# 2017 1st quarter (Jan-March)    0
# 2017 2nd quarter (Apr-June)     0
# 2017 3rd quarter (July-Sep)     0
# 2017 4th quarter (Oct-Dec)      0
# 2018 1st quarter (Jan-March)    0
# 2018 2nd quarter (Apr-June)     0
# 2018 3rd quarter (July-Sep)     0
# 2018 4th quarter (Oct-Dec)      0
# 2019 1st quarter (Jan-March)    0
# 2019 2nd quarter (Apr-June)     0
# 2019 3rd quarter (July-Sep)     0
# 2019 4th quarter (Oct-Dec)      0
# 2020 1st quarter (Jan-March)    0
# 2020 2nd quarter (Apr-June)     0
# 2020 3rd quarter (July-Sep)     0
# 2020 4th quarter (Oct-Dec)      0
# average_temp(*c)                0
# Relative Humidity(at 2m)%       0
# Precipitation (mm/day)          0
# Cultural Fests                  0
# Holidays                        0
# Total_Inflow                    0
# dtype: int64

# %%
df.to_csv("without_sc_encode_data.csv", index=False)

# %%
print(df.shape)
# Out:
# (63, 35)
